# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Criar um repositório Git local e fazer commit\n",
    "\n",
    "Este notebook mostra os passos principais para instalar/configurar Git, inicializar um repositório local, adicionar arquivos, fazer commit e verificar o histórico.\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Instalar e configurar o Git\n",
    "\n",
    "Instale o Git se necessário e configure seu nome de usuário e e-mail:\n",
    "\n",
    "```bash\n",
    "git config --global user.name \"Seu Nome\"\n",
    "git config --global user.email \"seu@email.com\"\n",
    "```\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Inicializar repositório local\n",
    "\n",
    "Use `git init` para criar um novo repositório Git no diretório atual:\n",
    "\n",
    "```bash\n",
    "git init\n",
    "```\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Adicionar arquivos ao repositório\n",
    "\n",
    "Use `git add` para colocar arquivos no stage antes do commit:\n",
    "\n",
    "```bash\n",
    "git add .\n",
    "```\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Fazer commit das alterações\n",
    "\n",
    "Use `git commit` para registrar as alterações com uma mensagem de commit:\n",
    "\n",
    "```bash\n",
    "git commit -m \"Mensagem do commit\"\n",
    "```\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Verificar histórico do commit\n",
    "\n",
    "Use `git log` para revisar o histórico de commits e confirmar que o commit foi criado:\n",
    "\n",
    "```bash\n",
    "git log --oneline\n",
    "```\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
